# %% [markdown]
# # With Charge

# %%
import random
import pandas as pd

# Initialize capital and other variables
capital = 10000
trades_per_day = 3
charge_per_trade = 50
max_loss = 0.3
# min_profit = 0.3
# min_profit = lambda: random.uniform(0.3, 1)
min_profit = lambda: 0.7

day_list = []
trade_list = []
tred_margin_list = []
status_list = []
profit_loss_list = []
profit_loss_percentage_list = []
tred_new_margin_list = []
capital_list = []
used_capital_list = []  # List to store Used_Capital

while capital >=  0 and capital <= 50000:  # Run until capital doubles or reaches zero
    capital_per_trade = capital / trades_per_day  # Divide capital equally among trades for the day

    for trade in range(1, trades_per_day + 1):
        # Simulate profit/loss using random choice
        is_profit = random.choice([True, False])  # True represents a profit, False represents a loss

        if is_profit:
            profit = ((capital_per_trade) * min_profit()) - charge_per_trade
            status = 'Profit'
        else:
            profit = -capital_per_trade * max_loss - charge_per_trade
            status = 'Loss'

        tred_margin = capital_per_trade
        tred_new_margin = tred_margin + profit - charge_per_trade  # Deduct the charge from the new margin
        capital += profit 
        used_capital = capital - profit 

        # Append trade data to the lists
        day_list.append(f'Day {len(day_list) // trades_per_day + 1}')
        trade_list.append(f'Tred {trade}')
        tred_margin_list.append(tred_margin)
        status_list.append(status)
        profit_loss_list.append(profit)
        profit_loss_percentage_list.append((profit / tred_margin) * 100)
        tred_new_margin_list.append(tred_new_margin)
        capital_list.append(capital)
        used_capital_list.append(used_capital)

# Create a pandas dataframe with the desired column order
data = {
    'Day': day_list,
    'Trade': trade_list,
    'Used_Capital': used_capital_list,
    'Tred_Margin': tred_margin_list,
    'Status': status_list,
    'Profit Loss': profit_loss_list,
    'Profit Loss%': profit_loss_percentage_list,
    'Tred_New_Margin': tred_new_margin_list,
    'Capital': capital_list,
}
df = pd.DataFrame(data)


if capital <= 0:
    print("Loss")
else:
    print("Target Achieved.")
    
print("Total Day ",df.shape[0]//3)
print("Total Tred ",df.shape[0])
loss_count = df[df['Status'] == 'Loss'].shape[0]
profit_count = df[df['Status'] == 'Profit'].shape[0]
print(f"Loss Count: {loss_count}")
print(f"Profit Count: {profit_count}")
# df.to_csv("Risk_management.csv")
df
# Out:
# Target Achieved.
# Total Day  43
# Total Tred  129
# Loss Count: 79
# Profit Count: 50
#         Day   Trade  Used_Capital   Tred_Margin  Status   Profit Loss  \
# 0     Day 1  Tred 1  10000.000000   3333.333333    Loss  -1050.000000
# 1     Day 1  Tred 2   8950.000000   3333.333333    Loss  -1050.000000
# 2     Day 1  Tred 3   7900.000000   3333.333333  Profit   2283.333333
# 3     Day 2  Tred 1  10183.333333   3394.444444    Loss  -1068.333333
# 4     Day 2  Tred 2   9115.000000   3394.444444    Loss  -1068.333333
# ..      ...     ...           ...           ...     ...           ...
# 124  Day 42  Tred 2  32866.316786  12191.228439  Profit   8483.859907
# 125  Day 42  Tred 3  41350.176693  12191.228439  Profit   8483.859907
# 126  Day 43  Tred 1  49834.036601  16611.345534    Loss  -5033.403660
# 127  Day 43  Tred 2  44800.632941  16611.345534    Loss  -5033.403660
# 128  Day 43  Tred 3  39767.229281  16611.345534  Profit  11577.941874
#
#      Profit Loss%  Tred_New_Margin       Capital
# 0      -31.500000      2233.333333   8950.000000
# 1      -31.500000      2233.333333   7900.000000
# 2       68.500000      5566.666667  10183.333333
# 3      -31.472995      2276.111111   9115.000000
# 4      -31.472995      2276.111111   8046.666667
# ..            ...              ...           ...
# 124     69.589869     20625.088347  41350.176693
# 125     69.589869     20625.088347  49834.036601
# 126    -30.300999     11527.941874  44800.632941
# 127    -30.300999     11527.941874  39767.229281
# 128     69.699001     28139.287407  51345.171154
#
# [129 rows x 9 columns]

# %% [markdown]
# # Testing RM

# %%
count_list = []
def main():
    import random
    import pandas as pd
    
    # Initialize capital and other variables
    capital = 50000
    trades_per_day = 3
    charge_per_trade = 50  
    max_loss = 0.4
    # min_profit = 0.4
    min_profit = lambda: random.uniform(0.3, 1) 
    # min_profit = lambda: 0.6
    
    
    
    day_list = []
    trade_list = []
    tred_margin_list = []
    status_list = []
    profit_loss_list = []
    profit_loss_percentage_list = []
    tred_new_margin_list = []
    capital_list = []
    used_capital_list = []  # List to store Used_Capital
    
    while capital >=  0 and capital <= 1000000:  # Run until capital doubles or reaches zero
        capital_per_trade = capital / trades_per_day  # Divide capital equally among trades for the day
    
        for trade in range(1, trades_per_day + 1):
            # Simulate profit/loss using random choice
            is_profit = random.choice([True, False])  # True represents a profit, False represents a loss
    
            if is_profit:
                profit = ((capital_per_trade) * min_profit()) - charge_per_trade
                status = 'Profit'
            else:
                profit = -capital_per_trade * max_loss - charge_per_trade
                status = 'Loss'
    
            tred_margin = capital_per_trade
            tred_new_margin = tred_margin + profit - charge_per_trade  # Deduct the charge from the new margin
            capital += profit 
            used_capital = capital - profit 
    
            # Append trade data to the lists
            day_list.append(f'Day {len(day_list) // trades_per_day + 1}')
            trade_list.append(f'Tred {trade}')
            tred_margin_list.append(tred_margin)
            status_list.append(status)
            profit_loss_list.append(profit)
            profit_loss_percentage_list.append((profit / tred_margin) * 100)
            tred_new_margin_list.append(tred_new_margin)
            capital_list.append(capital)
            used_capital_list.append(used_capital)
    
    # Create a pandas dataframe with the desired column order
    data = {
        'Day': day_list,
        'Trade': trade_list,
        'Used_Capital': used_capital_list,
        'Tred_Margin': tred_margin_list,
        'Status': status_list,
        'Profit Loss': profit_loss_list,
        'Profit Loss%': profit_loss_percentage_list,
        'Tred_New_Margin': tred_new_margin_list,
        'Capital': capital_list,
    }
    df = pd.DataFrame(data)
    
    
    if capital <= 0:
        # print("Loss")
        count_list.append("Loss")
    else:
        # print("Target Achieved.")
        count_list.append("Target")
   
        
    # print("Total Day ",df.shape[0]//3)
    # print("Total Tred ",df.shape[0])

for i in range(200):
    main()
    
loss_count, target_count = count_list.count('Loss'), count_list.count('Target')
print(f'Loss Count: {loss_count}, Target Count: {target_count}')
# Out:
# Loss Count: 1, Target Count: 199
