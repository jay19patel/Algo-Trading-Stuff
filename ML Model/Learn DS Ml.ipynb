# %% [markdown]
# ## Notes

# %%
import pandas as pd

# %% [markdown]
# ## Get Data

# %%
df = pd.read_csv("MainDataSet.csv")

# %%
# df["Status"] = (df['Pivot'] - df['Pivot'].shift(5) >= 60).shift(-6)

# %%
## Pandas

# %%
df
# Out:
#        Day_Open  Day_High   Day_Low  Day_Close  Day_Trend    Day_Date  \
# 0       17076.2  17109.45  16917.35   16945.05          1  2023-03-24
# 1       17076.2  17109.45  16917.35   16945.05          1  2023-03-24
# 2       17076.2  17109.45  16917.35   16945.05          1  2023-03-24
# 3       17076.2  17109.45  16917.35   16945.05          1  2023-03-24
# 4       17076.2  17109.45  16917.35   16945.05          1  2023-03-24
# ...         ...       ...       ...        ...        ...         ...
# 18354   21989.9  22080.95  21941.30   22011.95          1  2024-03-21
# 18355   21989.9  22080.95  21941.30   22011.95          1  2024-03-21
# 18356   21989.9  22080.95  21941.30   22011.95          1  2024-03-21
# 18357   21989.9  22080.95  21941.30   22011.95          1  2024-03-21
# 18358   21989.9  22080.95  21941.30   22011.95          1  2024-03-21
#
#        Day_SwingMin  Day_SwingMax             Datetime      Open  ...  \
# ...
