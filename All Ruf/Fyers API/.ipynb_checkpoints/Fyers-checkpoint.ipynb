# %%
from fyers_apiv3 import fyersModel
from datetime import datetime , timedelta
import pandas as pd
import pytz

# %% [markdown]
# # Genrate Token

# %%
client_id = "MACO3YJA7I-100"  # Replace with your client ID
secret_key = "N7SXUFQG91"  # Replace with your secret key
redirect_uri = "https://trade.fyers.in/api-login/redirect-uri/index.html"  # Replace with your redirect URI
response_type = "code" 
grant_type = "authorization_code"  
state = "sample_state"

# %% [markdown]
# ### Genearte Authcode

# %%
# # # Generate Auth Code
# session = fyersModel.SessionModel(
#     client_id=client_id,
#     secret_key=secret_key,
#     redirect_uri=redirect_uri,
#     response_type=response_type
# )
# genrate_authcode = session.generate_authcode()
# print(genrate_authcode)

# %%
auth_code = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....baZtV2Ao_bshpBOhxq2cz4Vxt787HmmGVaZWDWmVGSQ"

# %% [markdown]
# ### Set Session & Get TOKEN

# %%
session = fyersModel.SessionModel(
    client_id=client_id,
    secret_key=secret_key, 
    redirect_uri=redirect_uri, 
    response_type=response_type, 
    grant_type=grant_type
)
session.set_token(auth_code)
response = session.generate_token()
access_token = response['access_token']

# %% [markdown]
# # Login

# %%
access_token= "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.....08yC0yFYyEU4APozfM9Oo6f_E-KFXasLld8j1JCcYAA"

# %%
fyers = fyersModel.FyersModel(client_id=client_id, is_async=False, token=access_token, log_path="")

# %%
fyers.get_profile()
# Out:
# {'s': 'ok',
#  'code': 200,
#  'message': '',
#  'data': {'fy_id': 'YJ00129',
#   'name': 'JAYKUMAR DHANSUKHBHAI PATEL',
#   'image': None,
#   'display_name': None,
#   'pin_change_date': '18-12-2023 16:00:58',
#   'email_id': 'justjayy19@gmail.com',
#   'pwd_change_date': None,
#   'PAN': '---------',
#   'mobile_number': '7069668308',
#   'totp': True,
#   'pwd_to_expire': 90}}

# %%
# dir(fyers)

# %% [markdown]
# # Get Historical Data

# %%
def n_day_date(n):
    current_date = datetime.now()
    n_days_ago = current_date - timedelta(days=n)
    return n_days_ago.strftime('%Y-%m-%d')

# %%
def Historical_Data(Symbol,TimeFrame,Start_Date,End_Date):
    data = {
                "symbol":Symbol,
                "resolution":TimeFrame,
                "date_format":"1",
                "range_from":Start_Date,
                "range_to":End_Date,
                "cont_flag":"0"
            }
    row_data =  fyers.history(data=data)
    df = pd.DataFrame.from_dict(row_data['candles'])
    # columns_name = ['Datetime','Open','High','Low','Close','Volume']
    # df.columns = columns_name
    # df['Datetime'] = pd.to_datetime(df['Datetime'], unit='s')
    # df['Datetime'] = df['Datetime'].dt.tz_localize(pytz.utc).dt.tz_convert('Asia/Kolkata')
    # df['Datetime'] = df['Datetime'].dt.tz_localize(None)

    return df

# Symbol = "NSE:SBIN-EQ"
# TimeFrame = "15"

# Start_Date = n_day_date(5)
# End_Date = datetime.now().strftime('%Y-%m-%d')
# data = Historical_Data(Symbol,TimeFrame,Start_Date,End_Date)
# data

# %%
from datetime import datetime, timedelta

def generate_date_ranges():
    start_date = datetime(2015, 1, 1)
    end_date = datetime(2024, 1, 10)

    date_range_list = []
    current_date = start_date

    while current_date <= end_date:
        last_day_current = (current_date.replace(day=1) + timedelta(days=32)).replace(day=1) - timedelta(days=1)
        last_day_next = (last_day_current.replace(day=1) + timedelta(days=62)).replace(day=1) - timedelta(days=1)
        date_range_list.append((current_date, last_day_next))
        current_date = last_day_next + timedelta(days=1)

    return date_range_list

result = generate_date_ranges()

# %%
import pandas as pd

mydf = pd.DataFrame({})

for i in result:
    print(i[0].strftime('%Y-%m-%d'),i[1].strftime('%Y-%m-%d'))
    df = Historical_Data('NSE:NIFTY50-INDEX',"1",i[0].strftime('%Y-%m-%d'),i[1].strftime('%Y-%m-%d'))
    mydf = pd.concat([mydf, df], ignore_index=True)
# Out:
# 2015-01-01 2015-02-28
# 2015-03-01 2015-04-30
# 2015-05-01 2015-06-30
# 2015-07-01 2015-08-31
# 2015-09-01 2015-10-31
# 2015-11-01 2015-12-31
# 2016-01-01 2016-02-29
# 2016-03-01 2016-04-30
# 2016-05-01 2016-06-30
# 2016-07-01 2016-08-31
# 2016-09-01 2016-10-31
# 2016-11-01 2016-12-31
# 2017-01-01 2017-02-28
# 2017-03-01 2017-04-30
# 2017-05-01 2017-06-30
# 2017-07-01 2017-08-31
# 2017-09-01 2017-10-31
# 2017-11-01 2017-12-31
# 2018-01-01 2018-02-28
# 2018-03-01 2018-04-30
# 2018-05-01 2018-06-30
# 2018-07-01 2018-08-31
# 2018-09-01 2018-10-31
# 2018-11-01 2018-12-31
# 2019-01-01 2019-02-28
# 2019-03-01 2019-04-30
# 2019-05-01 2019-06-30
# 2019-07-01 2019-08-31
# 2019-09-01 2019-10-31
# 2019-11-01 2019-12-31
# 2020-01-01 2020-02-29
# 2020-03-01 2020-04-30
# 2020-05-01 2020-06-30
# 2020-07-01 2020-08-31
# 2020-09-01 2020-10-31
# 2020-11-01 2020-12-31
# 2021-01-01 2021-02-28
# 2021-03-01 2021-04-30
# 2021-05-01 2021-06-30
# 2021-07-01 2021-08-31
# 2021-09-01 2021-10-31
# 2021-11-01 2021-12-31
# 2022-01-01 2022-02-28
# 2022-03-01 2022-04-30
# 2022-05-01 2022-06-30
# 2022-07-01 2022-08-31
# 2022-09-01 2022-10-31
# 2022-11-01 2022-12-31
# 2023-01-01 2023-02-28
# 2023-03-01 2023-04-30
# 2023-05-01 2023-06-30
# 2023-07-01 2023-08-31
# 2023-09-01 2023-10-31
# 2023-11-01 2023-12-31
# 2024-01-01 2024-02-29

# %%
columns_name = ['Datetime','Open','High','Low','Close','Volume']
mydf.columns = columns_name

import pandas as pd
import pytz

# Assuming you have a DataFrame named 'mydf' with a column named 'Datetime'
mydf['Datetime'] = pd.to_datetime(mydf['Datetime'], unit='s')
mydf['Datetime'] = mydf['Datetime'].dt.tz_localize(pytz.utc).dt.tz_convert('Asia/Kolkata')
mydf['Datetime'] = mydf['Datetime'].dt.tz_localize(None)

# %%
# mydf.to_csv("2015_24_nifty50_1.csv")

# %% [markdown]
# # GET STOCK DATA

# %%
import pandas as pd
df = pd.read_csv("ind_nifty500list.csv")
def Get_Symbol(row):
    Symbol= row['Symbol'] 
    Series = "EQ"
    Ex = "NSE"
    Ticker = f"{Ex}:{Symbol}-{Series}"
    return Ticker
df['Tickers'] = df.apply(Get_Symbol,axis=1)
# df = df.sample(100)

# %%
def assess_liquidity_percentage(stock_data):
    try:
        data = {"symbols":stock_data['Tickers']}
        response = fyers.quotes(data=data)
        stock_data = response['d'][0]['v']
        
        volume_threshold = 1000000  # Adjust based on your criteria
        spread_threshold = 0.1  # Adjust based on your criteria
        price_difference_threshold = 5  # Adjust based on your criteria
    
        # 1. Volume
        volume_percentage = min(stock_data['volume'] / volume_threshold * 100, 100)
    
        # 2. Bid-Ask Spread
        spread_percentage = max(1 - stock_data['spread'] / spread_threshold, 0) * 100
    
        # 3. Price Alignment
        price_difference = abs(stock_data['open_price'] - stock_data['lp'])
        price_alignment_percentage = max(1 - price_difference / price_difference_threshold, 0) * 100
    
        # Calculate the overall percentage
        overall_percentage = (volume_percentage + spread_percentage + price_alignment_percentage) / 3
        return overall_percentage,stock_data['lp'], stock_data['chp']
    except:
        return None,None,None

# %%
df[['Status','Price','ChnagePr']] = df.apply(assess_liquidity_percentage,axis=1,result_type='expand')

# %%
filter_df1 = df[ (df['Status'] >= 50) & (df['Price'] <= 100 ) & (df['ChnagePr'] >= 0.7 )  ].sort_values(by='ChnagePr', ascending=False)

# %%
filter_df1
# Out:
#                            Company Name                           Industry  \
# 232                Indian Overseas Bank                 Financial Services
# 98                Central Bank of India                 Financial Services
# 436                 TV18 Broadcast Ltd.  Media Entertainment & Publication
# 28                 Alok Industries Ltd.                           Textiles
# 486                  Vodafone Idea Ltd.                  Telecommunication
# 198                           HFCL Ltd.                  Telecommunication
# 218                IDFC First Bank Ltd.                 Financial Services
# 333  Network18 Media & Investments Ltd.  Media Entertainment & Publication
#
#          Symbol Series     ISIN Code            Tickers     Status  Price  \
# 232         IOB     EQ  INE565A01014         NSE:IOB-EQ  74.333333  46.05
# 98    CENTRALBK     EQ  INE483A01010   NSE:CENTRALBK-EQ  73.666667  52.05
# 436  TV18BRDCST     EQ  INE886H01027  NSE:TV18BRDCST-EQ  77.000000  50.95
# 28     ALOKINDS     EQ  INE270A01029    NSE:ALOKINDS-EQ  81.333333  23.00
# 486        IDEA     EQ  INE669E01016        NSE:IDEA-EQ  82.000000  14.35
# 198        HFCL     EQ  INE548A01028        NSE:HFCL-EQ  77.333333  79.45
# 218  IDFCFIRSTB     EQ  INE092T01019  NSE:IDFCFIRSTB-EQ  83.000000  90.65
# 333   NETWORK18     EQ  INE870H01013   NSE:NETWORK18-EQ  63.000000  86.80
#
#      ChnagePr
# 232      3.02
# 98       2.97
# 436      2.31
# 28       1.77
# 486      1.77
# 198      1.74
# 218      1.00
# 333      0.70

# %%
import yfinance as yf
import pandas as pd
import ta
import pandas_ta as pdta

def Scan_stock(row):
    try:
        ticker = yf.Ticker(f"{row['Symbol']}.BO")
        df = ticker.history(period="500d", interval="1d")
        supertrend = pdta.supertrend(df['High'], df['Low'], df['Close'], length=7, multiplier=3)
        df['Trend'] = supertrend['SUPERTd_7_3.0']
        df['EMA_5'] = ta.trend.ema_indicator(df['Close'], window=5)
        df['EMA_200'] = ta.trend.ema_indicator(df['Close'], window=200)
        df['EMA_200'] = ta.trend.ema_indicator(df['Close'], window=200)
        df['RSI'] = pdta.momentum.rsi(df['Close'], window=14)
        df['Trend_signal'] = ((df['Trend'] == 1) & (df['Trend'].shift(1) == -1))
        df['RSI_signal'] = df['RSI'] <= 50
        df['Volume_signal'] = df['Volume'] > df['Volume'].rolling(window=20).mean()
        df['Buy'] = (df[['Trend_signal', 'RSI_signal', 'Volume_signal']].sum(axis=1) >= 2)
        df['SL'] = df['Close'].shift(1).rolling(window=60).min() 
        df['Target'] =  df['Close']  + (df['Close'] - df['SL'])*1.5
        return df.iloc[-1]['Buy'] ,df.iloc[-1]['SL'],df.iloc[-1]['Target']
    except Exception as e:
        return None, None, None

# %%
filter_df1[['Buy_Status','SL','Target']] = filter_df1.apply(Scan_stock,axis=1,result_type='expand')
# Out:
# ALOKINDS.BO: No data found, symbol may be delisted

# %%
# filter_df1[filter_df1['Buy_Status']].to_csv("today_tred.csv")

# %%
filter_df1
# Out:
#                            Company Name                           Industry  \
# 232                Indian Overseas Bank                 Financial Services
# 98                Central Bank of India                 Financial Services
# 436                 TV18 Broadcast Ltd.  Media Entertainment & Publication
# 28                 Alok Industries Ltd.                           Textiles
# 486                  Vodafone Idea Ltd.                  Telecommunication
# 198                           HFCL Ltd.                  Telecommunication
# 218                IDFC First Bank Ltd.                 Financial Services
# 333  Network18 Media & Investments Ltd.  Media Entertainment & Publication
#
#          Symbol Series     ISIN Code            Tickers     Status  Price  \
# 232         IOB     EQ  INE565A01014         NSE:IOB-EQ  74.333333  46.05
# 98    CENTRALBK     EQ  INE483A01010   NSE:CENTRALBK-EQ  73.666667  52.05
# 436  TV18BRDCST     EQ  INE886H01027  NSE:TV18BRDCST-EQ  77.000000  50.95
# 28     ALOKINDS     EQ  INE270A01029    NSE:ALOKINDS-EQ  81.333333  23.00
# 486        IDEA     EQ  INE669E01016        NSE:IDEA-EQ  82.000000  14.35
# 198        HFCL     EQ  INE548A01028        NSE:HFCL-EQ  77.333333  79.45
# 218  IDFCFIRSTB     EQ  INE092T01019  NSE:IDFCFIRSTB-EQ  83.000000  90.65
# 333   NETWORK18     EQ  INE870H01013   NSE:NETWORK18-EQ  63.000000  86.80
#
#      ChnagePr Buy_Status         SL      Target
# 232      3.02      False  37.209999   59.685003
# 98       2.97      False  42.549999   66.325005
# 436      2.31      False  40.450001   65.874996
# 28       1.77       None        NaN         NaN
# 486      1.77      False  10.730000   19.705000
# 198      1.74      False  63.389999  103.714993
# 218      1.00      False  81.110001  105.060005
# 333      0.70      False  63.209999  121.785000
